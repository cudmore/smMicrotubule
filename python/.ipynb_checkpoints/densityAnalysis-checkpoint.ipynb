# %% [markdown]
# Remember, we are using special package to but significance tests on top of plots using
#
# see: https://github.com/webermarcolivier/statannot
#
# ```
# pip install statannot
#
# # thenfrom statannot import add_stat_annotation
# ```

# %%
# This allows us to manually edit the code and have it reflected in this notebook
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pip freeze | grep tifffile
# Out:
# tifffile==0.15.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# import everything we need

import json # to prettyprint ordereddict

import numpy as np
import pandas as pd # using pd.__version__ == 0.24.2, There are newer versions and things might break!!!

print('pd.__version__:', pd.__version__)

import matplotlib.pyplot as plt

# %matplotlib inline

from IPython.display import display, clear_output
import ipywidgets

import tifffile # 20200707, I broke my virtual environment

from samiPostAnalysis import samiPostAnalysis
# Out:
# pd.__version__: 1.0.5

# %% [markdown]
# ### Create a samiPostAnalysis object with all of our sekelton analysis across groups (wtf, wtm, kof, kom)
#
# This assumes eveything has been processed with samiAnalysis.py
#
# In particular
#
# ```
# wtfPath = '../analysis/wt-female_results.csv'
# kofPath = '../analysis/ko-female_results.csv'
# wtmPath = '../analysis/wt-male_results.csv'
# komPath = '../analysis/ko-male_results.csv'
# ```

# %%
resultsPath = '/Users/cudmore/Desktop/samiVolume3'
resultsPath = '/Users/cudmore/Desktop/samiVolume4'

resultsPath = '/Users/cudmore/Desktop/samiVolume1'
#resultsPath = '/Users/cudmore/Desktop/samiVolume2'

spa = samiPostAnalysis(resultsPath)
# Out:
# samiPostAnalysis() is loading analysis files
#     loading: /Users/cudmore/Desktop/samiVolume1/wt-female_results.csv
#     loading: /Users/cudmore/Desktop/samiVolume1/ko-female_results.csv
#     loading: /Users/cudmore/Desktop/samiVolume1/wt-male_results.csv
#     loading: /Users/cudmore/Desktop/samiVolume1/ko-male_results.csv
#     loading densityResultsPath: /Users/cudmore/Desktop/samiVolume1/density-results.csv

# %% [markdown]
# ### Run density analysis
#
# This assumes everything has been processed by samiVolume2.py

# %%
pruneDict = spa.getDefaultPruneDict()
pruneDict['statName'] = 'len3d'
pruneDict['minValue'] = 1
pruneDict['branchType'] = [2]

df = spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)
#spa.densityPlot(pruneDict, 'dErodedToRing') # pass in one of (dFullMask  dErodedMask  dRingMask  dRingVsErodedRatio)
#spa.densityPlot(pruneDict, 'dRingToEroded') # pass in one of (dFullMask  dErodedMask  dRingMask  dRingVsErodedRatio)

display(df.head())
display(df.tail())
# Out:
#   genotype     sex  myCellNumber branchType statName  minValue    xVoxel  \
# 0       wt  female             0        [2]    len3d         1  0.209253
# 1       wt  female             1        [2]    len3d         1  0.089874
# 2       wt  female             2        [2]    len3d         1  0.199193
# 3       wt  female             3        [2]    len3d         1  0.230178
# 4       wt  female             4        [2]    len3d         1  0.207160
#
#      yVoxel  zVoxel  voxelVolume  ...  nPerVolFullMask  nPerVolErodedMask  \
# 0  0.209253    0.43     0.018828  ...         0.051052           0.118415
# 1  0.089874    0.43     0.003473  ...         0.076430           0.087067
# 2  0.199193    0.43     0.017061  ...         0.029970           0.097410
# 3  0.230178    0.43     0.022782  ...         0.039508           0.099556
# 4  0.207160    0.43     0.018454  ...         0.050019           0.137833
#
#    nPerVolRingMask  nPerVolRingToEroded  nPerVolErodedToRing  \
# 0         0.009905             8.364927          1195.467708
# 1         0.030431            34.950868           286.115928
# 2         0.000000             0.000000                  NaN
# 3         0.000000             0.000000                  NaN
# 4         0.000692             0.501845         19926.473483
#
#    mLenPerVolFullMask  mLenPerVolErodedMask  mLenPerVolRingMask  \
# 0            0.000305              0.000915            0.000775
# 1            0.000573              0.001937            0.001338
# 2            0.000291              0.000947                 NaN
# 3            0.000247              0.000627                 NaN
# 4            0.000330              0.000920            0.000725
#
#    mLenPerVolRingToEroded  mLenPerVolErodedToRing
# 0               84.682264              118.088482
# 1               69.065511              144.790067
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4               78.753761              126.978063
#
# [5 rows x 34 columns]
#     genotype   sex  myCellNumber branchType statName  minValue    xVoxel  \
# 125       ko  male            39        [2]    len3d         1  0.180139
# 126       ko  male            40        [2]    len3d         1  0.218063
# 127       ko  male            41        [2]    len3d         1  0.165728
# 128       ko  male            42        [2]    len3d         1  0.207160
# 129       ko  male            43        [2]    len3d         1  0.089874
#
#        yVoxel  zVoxel  voxelVolume  ...  nPerVolFullMask  nPerVolErodedMask  \
# 125  0.180139    0.43     0.013954  ...         0.052884           0.124108
# 126  0.218063    0.43     0.020447  ...         0.050920           0.133234
# 127  0.165728    0.43     0.011810  ...         0.069577           0.171529
# 128  0.207160    0.43     0.018454  ...         0.053173           0.142438
# 129  0.089874    0.43     0.003473  ...         0.083356           0.170099
#
#      nPerVolRingMask  nPerVolRingToEroded  nPerVolErodedToRing  \
# 125         0.005191             4.182634          2390.838128
# 126         0.000304             0.228181         43824.882660
# 127         0.008722             5.085002          1966.567753
# 128         0.000349             0.244845         40842.195954
# 129         0.000000             0.000000                  NaN
#
#      mLenPerVolFullMask  mLenPerVolErodedMask  mLenPerVolRingMask  \
# 125            0.000322              0.000858            0.000821
# 126            0.000279              0.000743            0.000313
# 127            0.000345              0.000963            0.000777
# 128            0.000341              0.000959            0.000366
# 129            0.000348              0.000723                 NaN
#
#      mLenPerVolRingToEroded  mLenPerVolErodedToRing
# 125               95.672779              104.522938
# 126               42.145298              237.274394
# 127               80.724869              123.877563
# 128               38.194634              261.816880
# 129                     NaN                     NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Run analysis twice and make two plots
#
# Temporary conclusion is the central/eroded region has higher density than the outer
#
# There is a problem here, my outer mask is going beyond the actual cell boundary. I need to run this multiple times (constructing different mask each time) by setting the threshold distance into euclidean-distrance transform to make outer masks bother farther and close to the actual bounary of the cell.

# %%
fig, axs = plt.subplots(1, 2, sharey=False, figsize=(20,10))
axs = np.ravel(axs) # flatten into 1D

#
# 1
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 1
pruneDict['branchType'] = [2]

spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)

ax = axs[0]
# pruneDict is ONLY used to generate x-axis labels
# pass in one of (dFullMask  dErodedMask  dRingMask  dRingToEroded, dErodedToRing)
spa.densityPlot(pruneDict, 'dErodedMask', ax=ax)

#
# 2
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 1
pruneDict['branchType'] = [2]

spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)

ax = axs[1]
# pruneDict is ONLY used to generate x-axis labels
# pass in one of (dFullMask  dErodedMask  dRingMask  dRingToEroded, dErodedToRing)
spa.densityPlot(pruneDict, 'dRingMask', ax=ax)

# %% [markdown]
# ## Run analysis 4 times with different branch/segment parameters

# %%
fig, axs = plt.subplots(2, 2, sharey=False, figsize=(15,20))
axs = np.ravel(axs) # flatten into 1D

# chose one of these
myStat = 'dErodedMask'
#myStat = 'dRingMask'
#myStat = 'dRingToEroded'
#myStat = 'dErodedToRing'
#myStat = 'vErodedMask'
#myStat = 'vRingMask'
#myStat = 'dFullMask'

#
# 1
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 0
pruneDict['branchType'] = []
spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)
ax = axs[0]
spa.densityPlot(pruneDict, myStat, ax=ax)

#
# 2
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 1
pruneDict['branchType'] = []
spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)
ax = axs[1]
spa.densityPlot(pruneDict, myStat, ax=ax)

#
# 3
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 1
pruneDict['branchType'] = [1,2]
spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)
ax = axs[2]
spa.densityPlot(pruneDict, myStat, ax=ax)

#
# 4
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 1
pruneDict['branchType'] = [2]
spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)
ax = axs[3]
spa.densityPlot(pruneDict, myStat, ax=ax)

# %%
# chose one of these
myStat = 'dErodedMask'
#myStat = 'dRingMask'
#myStat = 'dRingToEroded'
#myStat = 'dErodedToRing'
#myStat = 'vErodedMask'
#myStat = 'dFullMask'

#
# 1
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 0
pruneDict['branchType'] = []
spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, myStat)
print('statName:', myStat, pruneDict['minValue'], pruneDict['branchType'])
display(df1)

#
# 2
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 1
pruneDict['branchType'] = []
spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, myStat)
print('statName:', myStat, pruneDict['minValue'], pruneDict['branchType'])
display(df1)

#
# 3
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 1
pruneDict['branchType'] = [1,2]
spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, myStat)
print('statName:', myStat, pruneDict['minValue'], pruneDict['branchType'])
display(df1)

#
# 3
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 1
pruneDict['branchType'] = [2]
spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, myStat)
print('statName:', myStat, pruneDict['minValue'], pruneDict['branchType'])
display(df1)
# Out:
# statName: dErodedMask 0 []
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.989956   0.214443     0.119132    0.382763
# 1    (wt, male)                 0.99667     0.695493    0.784727
# 2  (ko, female)                             0.991769    0.501218
# 3    (ko, male)                                         0.996160
# statName: dErodedMask 1 []
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.989956   0.189662    0.0394994    0.271111
# 1    (wt, male)                 0.99667      0.66726    0.657525
# 2  (ko, female)                             0.991769    0.425229
# 3    (ko, male)                                         0.996160
# statName: dErodedMask 1 [1, 2]
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.989956   0.189662    0.0517518    0.284552
# 1    (wt, male)                 0.99667     0.603242    0.557451
# 2  (ko, female)                             0.991769    0.270259
# 3    (ko, male)                                         0.996160
# statName: dErodedMask 1 [2]
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.989956  0.0993034    0.0153947    0.382763
# 1    (wt, male)                 0.99667     0.445121    0.427996
# 2  (ko, female)                             0.991769    0.094715
# 3    (ko, male)                                         0.996160

# %% [markdown]
# ## Make an interface to vary (minValue, branchType)

# %%
global spa1, spa2
global df1a, df2a, df1n, df2n

# 1
resultsPath1 = '/Users/cudmore/Desktop/samiVolume1'
spa1 = samiPostAnalysis(resultsPath1)
pruneDict1 = spa1.getDefaultPruneDict()
pruneDict1['branchType'] = []
pruneDict1['minValue'] = 0
myStat1 = 'dErodedMask'
spa1.densityCalculateAll(pruneDict1) # when we change detection parameters, we need this again (slow)
df1a, df1b = spa1.densityGetPairwiseGroupComparison(pruneDict1, myStat1)
#df1a, df1b = spa.getPairwiseGroupComparison(pruneDict1, doCellMean=True)
#df1n = spa.getCounts(pruneDict1, asDict=False)

# 2
resultsPath2 = '/Users/cudmore/Desktop/samiVolume2'
spa2 = samiPostAnalysis(resultsPath2) # load
pruneDict2 = spa2.getDefaultPruneDict()
pruneDict2['branchType'] = []
pruneDict2['minValue'] = 0
myStat2 = 'dRingMask'
spa2.densityCalculateAll(pruneDict1) # when we change detection parameters, we need this again (slow)
df2a, df2b = spa1.densityGetPairwiseGroupComparison(pruneDict2, myStat2)
#df1a, df1b = spa.getPairwiseGroupComparison(pruneDict1, doCellMean=True)
#df1n = spa.getCounts(pruneDict1, asDict=False)
# Out:
# samiPostAnalysis() is loading analysis files
#     loading: /Users/cudmore/Desktop/samiVolume1/wt-female_results.csv
#     loading: /Users/cudmore/Desktop/samiVolume1/ko-female_results.csv
#     loading: /Users/cudmore/Desktop/samiVolume1/wt-male_results.csv
#     loading: /Users/cudmore/Desktop/samiVolume1/ko-male_results.csv
#     loading densityResultsPath: /Users/cudmore/Desktop/samiVolume1/density-results.csv
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# samiPostAnalysis() is loading analysis files
#     loading: /Users/cudmore/Desktop/samiVolume2/wt-female_results.csv
#     loading: /Users/cudmore/Desktop/samiVolume2/ko-female_results.csv
#     loading: /Users/cudmore/Desktop/samiVolume2/wt-male_results.csv
#     loading: /Users/cudmore/Desktop/samiVolume2/ko-male_results.csv
#     loading densityResultsPath: /Users/cudmore/Desktop/samiVolume2/density-results.csv

# %%
def loadAndAnalyze(resultsPath, branchType, minValue, myStat):
    print('please wait ...')
    spa = samiPostAnalysis(resultsPath) # load
    pruneDict = spa.getDefaultPruneDict()
    pruneDict['branchType'] = branchType
    pruneDict['minValue'] = minValue
    print('. densityCalculateAll ...')
    spa.densityCalculateAll(pruneDict) # when we change detection parameters, we need this again (slow)
    dfa, dfb = spa1.densityGetPairwiseGroupComparison(pruneDict, myStat)
    return spa, dfa, dfb

from ipywidgets import Layout, Button, Box

global myStat1, myStat2
myStat1 = 'dRingMask'
myStat2 = 'dErodedMask'

branchTypeList = [[], [0], [1], [2], [3], [1,2]]

maskTypeList = [['dRingMask'], ['dErodedMask']]

global folderBase
folderBase = '/Users/cudmore/Desktop/samiVolume'
loadFolderList = ['1', '2', '3', '4']

# put controls in an H Box layout
myHBoxLayout1 = Layout(display='flex',
                    flex_flow='row',
                    align_items='stretch',
                    border='solid 1px',
                    width='100%')

#
# 1
branchTypeName1 = 'Branch Type 1'
style = {'description_width': 'initial'}
branchType_Dropdown1 = ipywidgets.Dropdown(
    options=branchTypeList,
    value=[],
    style=style,
    description=branchTypeName1,
)

minValue1 = 'Min Value 1'
minValue_FloatSlider1 = ipywidgets.FloatSlider(
    value=0,
    min=0,
    max=10.0,
    step=0.1,
    description=minValue1,
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)

maskTypeName1 = 'Mask 1'
style = {'description_width': 'initial'}
maskType_Dropdown1 = ipywidgets.Dropdown(
    options=maskTypeList,
    value=maskTypeList[0],
    style=style,
    description=maskTypeName1,
)

loadFolderName1 = 'Folder Name 1'
style = {'description_width': 'initial'}
folderName_Dropdown1 = ipywidgets.Dropdown(
    options=loadFolderList,
    value=loadFolderList[0],
    style=style,
    description=loadFolderName1,
)


items = [branchType_Dropdown1, minValue_FloatSlider1, maskType_Dropdown1, folderName_Dropdown1]
hBox1 = Box(children=items, layout=myHBoxLayout1)
#display(hBox1)

def myDisplay():
    # 1
    display(df1a)
    #display(df1n)
    display(hBox1)
    # 2
    '''
    display(df2a)
    #display(df2n)
    display(hBox2)
    '''
    
def on_change(change):
    global spa1, spa2
    global df1a, df2a, df1n, df2n
    global myStat1, myStat2
    if change['type'] == 'change' and change['name'] == 'value':
        #print('change:', change)
        #print('=== change["owner"].description:', change["owner"].description)
        #print('changed to:', change['new'], type(change['new']))
        newValue = change['new'] # can be (str, float)
        description = change["owner"].description
        #print('description:', description)
        
        # 1
        if description == branchTypeName1:
            print('rewrite code')
            pass
            pruneDict1['branchType'] = newValue
            df1a, df1b = spa.getPairwiseGroupComparison(pruneDict1, doCellMean=True)
            df1n = spa.getCounts(pruneDict1, asDict=False)
            #
            clear_output(wait=True)
            myDisplay()
        elif description == minValue1:
            print('rewrite code')
            pass
            pruneDict1['minValue'] = newValue
            df1a, df1b = spa.getPairwiseGroupComparison(pruneDict1, doCellMean=True)
            df1n = spa.getCounts(pruneDict1, asDict=False)
            #
            clear_output(wait=True)
            myDisplay()
        elif description == loadFolderName1:
            newFolder = folderBase + str(newValue)
            # load folder, analyze all density and get density pairwise
            spa1, df1a, df1b = loadAndAnalyze(newFolder, pruneDict1['branchType'], pruneDict1['minValue'], myStat1)
            #
            clear_output(wait=True)
            myDisplay()            
        elif description == maskTypeName1:
            # don't density calculate all
            myStat1 = newValue[0]
            print('myStat1:', myStat1)
            df1a, df1b = spa1.densityGetPairwiseGroupComparison(pruneDict1, myStat1)
            #
            clear_output(wait=True)
            myDisplay()

        # 2
        elif description == branchTypeName2:
            pruneDict2['branchType'] = newValue
            df2a, df2b = spa.getPairwiseGroupComparison(pruneDict2, doCellMean=True)
            df2n = spa.getCounts(pruneDict2, asDict=False)
           #
            clear_output(wait=True)
            myDisplay()
        elif description == minValueName2:
            pruneDict2['minValue'] = newValue
            df2a, df2b = spa.getPairwiseGroupComparison(pruneDict2, doCellMean=True)
            df2n = spa.getCounts(pruneDict2, asDict=False)
           #
            clear_output(wait=True)
            myDisplay()

# 1
branchType_Dropdown1.observe(on_change)
minValue_FloatSlider1.observe(on_change)
maskType_Dropdown1.observe(on_change)
folderName_Dropdown1.observe(on_change)
# 2
#branchType_Dropdown2.observe(on_change)
#minValue_FloatSlider2.observe(on_change)

myDisplay()
# Out:
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.989956   0.214443     0.119132    0.175844
# 1    (wt, male)                 0.99667     0.695493    0.767032
# 2  (ko, female)                             0.991769    0.882673
# 3    (ko, male)                                         0.996670
# Box(children=(Dropdown(description='Branch Type 1', options=([], [0], [1], [2], [3], [1, 2]), style=Descriptio…

# %% [markdown]
# ## For different sets of parameters compare dRing and/or dEroded within each (genotype, sex)

# %%
pruneDict = spa.getDefaultPruneDict()

#
# 1
statName = 'dRingMask'

pruneDict['minValue'] = 1
pruneDict['branchType'] = [2]
spa.densityCalculateAll(pruneDict) # when we change detection parameters, we need this again (slow)
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, statName)
print('statName:', statName, pruneDict['minValue'], pruneDict['branchType'])
display(df1)

pruneDict['minValue'] = 1
pruneDict['branchType'] = [1,2]
spa.densityCalculateAll(pruneDict) # when we change detection parameters, we need this again (slow)
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, statName)
print('statName:', statName, pruneDict['minValue'], pruneDict['branchType'])
display(df1)

#
# 2
statName = 'dErodedMask'

pruneDict['minValue'] = 1
pruneDict['branchType'] = [2]
spa.densityCalculateAll(pruneDict) # when we change detection parameters, we need this again (slow)
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, statName)
print('statName:', statName, pruneDict['minValue'], pruneDict['branchType'])
display(df1)

pruneDict['minValue'] = 1
pruneDict['branchType'] = [1,2]
spa.densityCalculateAll(pruneDict) # when we change detection parameters, we need this again (slow)
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, statName)
print('statName:', statName, pruneDict['minValue'], pruneDict['branchType'])
display(df1)
# Out:
# statName: dRingMask 1 [2]
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.990575   0.853452     0.850723    0.760558
# 1    (wt, male)                0.996651      0.55671    0.881458
# 2  (ko, female)                             0.991705    0.532585
# 3    (ko, male)                                         0.996108
# statName: dRingMask 1 [1, 2]
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.990626   0.759161     0.921038    0.663404
# 1    (wt, male)                 0.99666     0.443533    0.960550
# 2  (ko, female)                             0.991733    0.512343
# 3    (ko, male)                                         0.996138
# statName: dErodedMask 1 [2]
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.989956  0.0993034    0.0153947    0.382763
# 1    (wt, male)                 0.99667     0.445121    0.427996
# 2  (ko, female)                             0.991769    0.094715
# 3    (ko, male)                                         0.996160
# statName: dErodedMask 1 [1, 2]
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.989956   0.189662    0.0517518    0.284552
# 1    (wt, male)                 0.99667     0.603242    0.557451
# 2  (ko, female)                             0.991769    0.270259
# 3    (ko, male)                                         0.996160

# %% [markdown]
# ## get stat tests on plot
#
# see: https://github.com/webermarcolivier/statannot
#
# pip install statannot

# %%
import seaborn as sns
from statannot import add_stat_annotation

sns.set(style="whitegrid")

# %% [markdown]
# ### rerun full density analysis

# %%
pruneDict = spa.getDefaultPruneDict()
pruneDict['minValue'] = 1 # print <1 len3d
pruneDict['branchType'] = [2] #[2]

df = spa.densityCalculateAll(pruneDict) # uses (statName, minValue, branchType)

statName = 'dErodedMask'
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, statName)
print('statName:', statName, pruneDict['minValue'], pruneDict['branchType'])
display(df1)

statName = 'dRingMask'
df1, df2 = spa.densityGetPairwiseGroupComparison(pruneDict, statName)
print('statName:', statName, pruneDict['minValue'], pruneDict['branchType'])
display(df1)
# Out:
# statName: dErodedMask 1 [2]
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.989956  0.0993034    0.0153947    0.382763
# 1    (wt, male)                 0.99667     0.445121    0.427996
# 2  (ko, female)                             0.991769    0.094715
# 3    (ko, male)                                         0.996160
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:234: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /Users/cudmore/opt/anaconda3/envs/sami_env/lib/python3.6/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# statName: dRingMask 1 [2]
#          groups (wt, female) (wt, male) (ko, female)  (ko, male)
# 0  (wt, female)     0.990575   0.853452     0.850723    0.760558
# 1    (wt, male)                0.996651      0.55671    0.881458
# 2  (ko, female)                             0.991705    0.532585
# 3    (ko, male)                                         0.996108

# %% [markdown]
#         Statistical test to run. Must be one of:
#         - `Levene`
#         - `Mann-Whitney`
#         - `Mann-Whitney-gt`
#         - `Mann-Whitney-ls`
#         - `t-test_ind`
#         - `t-test_welch`
#         - `t-test_paired`
#         - `Wilcoxon` (requires same number of observations)
#         - `Kruskal`

# %%
# check volumes
#myStat = 'vFullMask'
#myStat = 'vErodedMask'
#myStat = 'vRingMask'

# 'd' is sum 3d len / vol

myStat = 'dErodedMask' # ko female goes down !
myStat = 'dRingMask' # no change

#myStat = 'dErodedToRing'
#myStat = 'dRingToEroded'

#myStat = 'nPerVolFullMask'
#myStat = 'nPerVolErodedMask' # ko female goes down !
#myStat = 'nPerVolRingMask'

#myStat = 'nPerVolErodedToRing' # always greater
#myStat = 'nPerVolRingToEroded' # always less than 1 (100)

#myStat = 'mLenPerVolFullMask'
#myStat = 'mLenPerVolErodedMask'
#myStat = 'mLenPerVolRingMask'

#myStat = 'mLenPerVolRingToEroded'
#myStat = 'mLenPerVolErodedToRing'

myStatTest = 'Mann-Whitney' # ('Kruskal', 'Mann-Whitney', 'Mann-Whitney-gt', 't-test_ind')
comparisons_correction = None # from ('bonferroni', None)

text_format = 'star' #'simple'

#import matplotlib.pyplot as plt
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20

fig, axs = plt.subplots(1, 1, sharey=False, figsize=(4,4))
axs = np.ravel(axs) # flatten into 1D

x = 'genotype'
y = myStat
hue = 'sex'
hue_order=['female', 'male']

box_pairs=[
    (("wt", "female"), ("wt", "male")),
    (("ko", "female"), ("ko", "male")),

    (("wt", "female"), ("ko", "female")),
    (("wt", "male"), ("ko", "male")),

    (("wt", "female"), ("ko", "male")),
    (("wt", "male"), ("ko", "female")),
    ]

# boxplot
#ax = sns.boxplot(data=df, x=x, y=y, hue=hue, ax=axs[0]) # no way to turn off outliers
# bar plot with ALMOST sem
ax = sns.barplot(data=df, x=x, y=y, hue=hue, ax=axs[0], capsize=0.1, ci=68) # CAREFUL, ci=68 ASSUMES A NORMAL DISTRIBUTION

ax.set_ylim([0,0.04]) # ring
#ax.set_ylim([0,0.4]) # eroded

            # set verbose >0 to print all stat tests
if 1:
    axNew, test_result_list = add_stat_annotation(ax, data=df, x=x, y=y, hue=hue, box_pairs=box_pairs,
                    test=myStatTest, comparisons_correction=comparisons_correction,
                    loc='outside', text_format=text_format, fontsize='x-large', verbose=0)

plt.legend(loc='upper left', bbox_to_anchor=(1.03, 1));
